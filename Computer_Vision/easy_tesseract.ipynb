# %%
from PIL import Image
import pytesseract
import matplotlib.pyplot as plt
import cv2

# %%
pytesseract.pytesseract.tesseract_cmd = r'C:\Program Files\Tesseract-OCR\tesseract.exe'

# %%
# %ls
# Out:
#  C 드라이브의 볼륨에는 이름이 없습니다.
#  볼륨 일련 번호: 88C3-9794
#
#  C:\Users\ezmedicom\Desktop\VisionAPI 디렉터리
#
# 2021-06-02  오후 02:47    <DIR>          .
# 2021-06-02  오후 02:47    <DIR>          ..
# 2021-06-02  오후 02:43    <DIR>          .ipynb_checkpoints
# 2021-06-02  오후 02:39           153,750 35r6110.jpg
# 2021-05-27  오후 02:49         2,290,266 KakaoTalk_20210527_143110822_03.jpg
# 2021-06-02  오후 02:43         3,193,280 Untitled.ipynb
# 2021-06-02  오후 02:47               726 Untitled1.ipynb
# 2021-06-01  오후 03:24                 0 VisionAPI.py
# 2021-06-01  오후 02:29             2,321 visionapi-315505-e7d62fd5df0c.json
#                6개 파일           5,640,343 바이트
#                3개 디렉터리  123,458,265,088 바이트 남음

# %%
img_original = cv2.imread('35r6110.jpg')

height, width, channel = img_original.shape

plt.figure(figsize = (12,10))
plt.imshow(img_original, cmap = 'gray')

# %%
text = pytesseract.image_to_string(Image.open('35r6110.jpg'), lang = 'kor')
print(text)
